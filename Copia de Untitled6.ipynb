# %%
i=int(input("ingrese el numero n: "))
suma1=1
if (5%4!=1):
   for i in range (1,5+4):
     suma=i(i+1)
     suma1+=suma
print(f"la suma de numeros es: {suma1}")


i=int(input("ingrese el numero n: "))
suma1=0
if (3%(-3)!=0):
   for i in range (1,3+3):
     suma=2**n
     suma1+=suma
print(f"la suma de numeros es: {suma1}")


i=int(input("ingrese el numero n: "))
suma1=1
if (100%(-99)!=1):
   for i in range (1,100+(-99)):
     suma=4
     suma1+=suma
print(f"la suma de numeros es: {suma1}")
# Out:
# ingrese el numero n: 5
# la suma de numeros es: 1
# ingrese el numero n: 3
# la suma de numeros es: 0
# ingrese el numero n: 100
# la suma de numeros es: 1
