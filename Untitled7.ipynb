# %%
#float = flotantes, strinsg = textos, int = enteros, bool = booleanos (true o false) concaterner : +
juan = 8 
Carlos = "Hombre"
numero = 3.2
Andres = " de 30 años"
Num_elegido = input("escribe un numero de 1 a 10")
# Out:
# escribe un numero de 1 a 105

# %%
print(Num_elegido)
# Out:
# 5

# %%
parte_entera = int(numero)
print(parte_entera)
# Out:
# 3

# %%
es_estudiante = True
trabaja = False
es_estudiante and trabaja
# Out:
# False

# %%
numero1 = 5
numero2 = 5
numero3 = 7
numero1 <= numero3
# Out:
# True

# %%
#listas
variable = [1,5,7,9]
variable2 = [3,4.6, 'hi', True]

# %%
variable2.append(False)
print(variable2)

# %%
import numpy as np
#escalar: es un numero y en python ese numero puede ser entero (int), flotante (float), texto (string)
escalar = 3
#vector
vector_fila = np.array([1,2,3])
print(vector_fila)
# Out:
# [1 2 3]

# %%
matriz = np.array([[1,2,3],[4,5,6]])
print(matriz)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#funcion para saber las dimensiones .shape ------ cantidad de elementos len()
matriz.shape
# Out:
# (2, 3)

# %%
matriz_Transp = matriz.T
print(matriz_Transp)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
multiplica_esc_matriz = escalar*matriz
print(multiplica_esc_matriz)
# Out:
# [[ 3  6  9]
#  [12 15 18]]

# %%
#multiplicar matricices
A= np.array([[3,4,5],[5,-1,0],[1,2,-3]])
B= np.array([[1,2],[0,1],[2,1]])
D= A.dot(B)
print(0)
# Out:
# 0
