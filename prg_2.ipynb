# %% [markdown]
# EJERCICIO 1:
#
# Dos pueblos que distancia 12 km estan unidos por una carrera recta. Un ciclista viaja de un pueblo al otro con una velocidad constante de 10 m/s.
# Calcula el tiempo que emplea
#
# DESCRIPCION DEL ENUNCIADO:
#
# AUTOR: JUAN CAMILO LOPEZ OSPINA
#
# FECHA:
#
# VERSION: 1.0

# %%
### Programa de Fisica

# %%
# Declaracion de variables
var_int_distanciaentrepueblos = 0 # Varible donde se captura la distancia
