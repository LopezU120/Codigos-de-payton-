# %%
def comparar(n1,n2):
    cont=1
    digit=0
    while cont<=n1:
        digit=n1/10
        n1=n1//10
        cont+=1
# Llamado de la funcion
numero1= int(input("Digite Numero entero : "))
numero2 = int(input("Digite un digito : "))
print("El digito es : %d ", comparar n1,n2))
# Out:
#   File "<ipython-input-17-7b94ec6706ad>", line 11
#     print("El digito es : %d ", % comparar n1,n2))
#                                 ^
# SyntaxError: invalid syntax
