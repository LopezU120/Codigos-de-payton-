# %%
import math
rad= float(input("ingrese radio del circulo: "))
area=math.pi*pow(rad,2)
longitud=2*math.pi*rad
print("el area del ciruclo es: ", area)
print("la longitud del circulo es: ", longitud)
# Out:
# ingrese radio del circulo: 70
# el area del ciruclo es:  15393.804002589986
# la longitud del circulo es:  439.822971502571

# %%
distancia= int(input("ingrese una distancia que desee recorrer: "))
tiempo= int(input("ingrese el timepo: "))
velocidad= distancia/tiempo
print("la velovidad requeria es: ", velocidad)
# Out:
# ingrese una distancia que desee recorrer: 4
# ingrese el timepo: 3
# la velovidad requeria es:  1.3333333333333333

# %%
lado1=float(input("ingrese el valor del lado 1: "))
lado2=float(input("ingrese el valor del lado 2: "))
area= lado1*lado2
perimetro= (lado1*2)+(lado2*2)
print("el area es: ", area)
print("el perimeto es: ", perimetro)
# Out:
# ingrese el valor del lado 1: 3
# ingrese el valor del lado 2: 3
# el area es:  9.0
# el perimeto es:  12.0

# %%
# FUNCION DESARROLADA POR EL PROGRAMDOR
# Funcion sin recibir parametros ni retornar valor
# Prototipo 
def calculcarAreaPerimetro():   
# Desarrollo
    lado1=float(input("ingrese el valor del lado 1: "))
    lado2=float(input("ingrese el valor del lado 2: "))
    area= lado1*lado2
    perimetro= (lado1*2)+(lado2*2)
    print("el area es: ", area)
    print("el perimeto es: ", perimetro)

# Llamado

calculcarAreaPerimetro()
# Out:
# ingrese el valor del lado 1: 5
# ingrese el valor del lado 2: 4
# el area es:  20.0
# el perimeto es:  18.0

# %%
# FUNCION DESARROLADA POR EL PROGRAMDOR
# Funcion sin recibir parametros ni retornar valor
# Prototipo 
def calculcarAreaPerimetro(p_ladoUno,p_ladoDos):   
# Desarrollo
    area= lado1*lado2
    perimetro= (lado1*2)+(lado2*2)
    print("el area es: ", area)
    print("el perimeto es: ", perimetro)

# Fin de desarrollo de la funcion

# Llamado
lado1=float(input("ingrese el valor del lado 1: "))
lado2=float(input("ingrese el valor del lado 2: "))
calculcarAreaPerimetro(lado1,lado2)
# Out:
# ingrese el valor del lado 1: 6
# ingrese el valor del lado 2: 4
# el area es:  24.0
# el perimeto es:  20.0

# %%
# FUNCION DESARROLADA POR EL PROGRAMDOR
# Funcion sin recibir parametros ni retornar valor
# Prototipo 
def calculcarArea():   
# Desarrollo
    lado1=float(input("ingrese el valor del lado 1 "))
    lado2=float(input("ingrese el valor del lado 2 "))
    area = lado1*lado2
    return(area)
# Fin de desarrollo de la funcion

# Llamado
print("El area es: ", calculcarArea())
# Out:
# ingrese el valor del lado 1 4
# ingrese el valor del lado 2 4
# El area es:  16.0

# %%
# FUNCION DESARROLADA POR EL PROGRAMDOR
# Funcion sin recibir parametros ni retornar valor
# Prototipo 
def calculcarPerimetro(p_lado1,p_lado2):   
# Desarrollo
    perimetro= (p_lado1*2)+(p_lado2*2)
    return(perimetro)
# Fin de desarrollo de la funcion

# Llamado
lado1=float(input("ingrese el valor del lado 1: "))
lado2=float(input("ingrese el valor del lado 2: "))
print("el perimetro es : ", calcularPerimetro(lado1,lado2))
