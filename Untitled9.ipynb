# %%
#Funciones de manejo de cadenas 
mensaje1 = 'Hola' + ' ' + 'Mundo'
print(mensaje1)
# Out:
# Hola Mundo

# %%
nombre = ''
apellidos = ''
nombrecompleto = ''

nombre = input("digite nombre : ")
apelidos = input("Digite Apellidos : ")

nombrecompleto = nombre+" "+apellidos
print("Su nombre completo es : ",nombrecompleto)
# Out:
# digite nombre : Juan Camilo
# Digite Apellidos : Lopez Ospina
# Su nombre completo es :  Juan Camilo

# %%
mensaje2a = 'Hola ' * 10
mensaje2b = 'Mundo'
print(mensaje2a + mensaje2b)
# Out:
# Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Mundo

# %%
mensaje5 = "Hola Mundo"
mensaje5a = mensaje5.find("Mundo")
print(mensaje5a)
# Out:
# 5

# %%
def BuscarPosCad(texto,Buscar):
    pos = texto.find(Buscar)
    return pos 
#Declar variables
# Llamado de a funcion
textoleer = input("Digite cadena origen : ")
textoBuscar = input("Digite Texto a buscar : ")
# Llamado de a funcion
res = BuscarPosCad(textoleer,textoBuscar)
print("posicion : ",str(res))
# Out:
# Digite cadena origen : Manizales
# Digite Texto a buscar : i
# posicion :  3

# %%
mesanje9 = "Hola Mundo"
print(mensaje9[:5])
