# %% [markdown]
# Un formula 1 que parte del reposo alcanza una velocidad de 216m/S en 10s
#
# autor: Juan Camilo Lopez
#
# Fecha: 06_09_2022
#
# Version: 1.0

# %%
# Declaracion de variables
var_ent_float_velocidadIncial = 0.0
var_ent_float_velocidadFinal = 0.0
var_ent_float_Tiempo = 0.0
var_proSal_float_aceleracion = 0.0 # Variable que almacena

# %%
# Captura de datos
var_ent_float_velocidadIncial = float(input("velocidad Incial ;"))
var_ent_float_velocidadFinal = float(input("velocidad Final ;"))
var_ent_float_Tiempo = float(input("Tiempo ;"))
# Out:
# velocidad Incial ;0
# velocidad Final ;60
# Tiempo ;10

# %% [markdown]
# Velocidad Inicial: 0
#
# Velocida Final: 60
#
# Tiempo: 10

# %%
# Procesos
var_proSal_float_aceleracion = (var_ent_float_velocidadFinal-var_ent_float_velocidadIncial)/var_ent_float_Tiempo

# %%
# Salida
print(var_proSal_float_aceleracion)
# Out:
# 6.0
