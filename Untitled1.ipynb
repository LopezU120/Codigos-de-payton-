# %%
print('Hello world!')
# Out:
# Hello world!

# %%
nombre = 'Juan'
print(nombre)
# Out:
# Juan

# %%
nombre = 'Luis'
print('Hello', nombre)
print(f'Hello {nombre}')
# Out:
# Hello Luis
# Hello Luis

# %%
nombre_usuario = input('Ingrese tu nombre ')
edad = int(input('Edad: '))
# Valida si la persona es mayor de edad 
if edad >= 18:
 print('Es mayor de edad')
else: 
 print('Es menor de edad')
# Out:
# Ingrese tu nombre Juan
# Edad: 14
# Es menor de edad
