# %%
i=int(input("ingrese el numero n: "))
suma1=70
if (5%2!=1):
   for i in range (1,5*2):
     multi=i*(i+1)
     suma1+=multi
print(f"la suma de numeros es: {suma1}")


i=int(input("ingrese el numero n: "))
suma1=14
if ("3%8!<=0"):
   for i in range (1,3+8):
     suma=2**8
     suma1+=suma
print(f"la suma de numeros es: {suma1}")


i=int(input("ingrese el numero n: "))
suma1=400
if (100%400!=1):
   for i in range (1,100+400):
     suma=4
     suma1+=suma
print(f"la suma de numeros es: {suma1}")
# Out:
# ingrese el numero n: 5
# la suma de numeros es: 70
# ingrese el numero n: 3
# la suma de numeros es: 2574
# ingrese el numero n: 100
# la suma de numeros es: 2396
