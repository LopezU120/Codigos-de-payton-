# %% [markdown]
# 4. Constuir una funcion que reciba como parametro un entero y retorne sus dos ultimos digitos.
#
# Autor : Juan Camilo Lopez O
#
# Fecha : 05_10_2022
#
# Ficha : 1.0

# %%
# Desarrolo de la funcion 

def Cant_DigPares(Num):
    Num = 0
    CantDigPares = 0
    Cant_Dig_Pares = 0
    Mientras = Num>0
    UltDig = Num - 10
    CantDigPares = CantDigPares + 1
    Num = Num/10
    return(CantDigPares)

# Llamado de la funcion 

valor = int(input("Digite Numero : "))
print("El ultimo Digito es :", CantDigPares(valor))
