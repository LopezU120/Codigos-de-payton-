# %% [markdown]
# Calcular el area de un cono de altura inclinada de 15cm y un diametro de 6cm
#
# Autor: Juan Camilo Lopez
#
# Fecha: 06_09_2022
#
# Version: 1.0

# %%
# Declarion de variables
var_ent_float_alturaInclinada = 0.0
var_ent_float_Radio = 0.0
var_ent_float_diametro = 0.0
var_proSal_float_Area = 0.0 # variable que almacena

# %%
# Captura de datos 
var_ent_float_alturaInclinada = float(input("altura Inclinada ;"))
var_ent_float_Radio = float(input("Radio ;"))
var_ent_float_diametro = float(input("diametro ;"))
# Out:
# altura Inclinada ;15
# Radio ;3
# diametro ;6

# %% [markdown]
# Altura Inclinada; 15
#
# Radio; 3
#
# Diametro; 6

# %%
# Procesos 
var_proSal_float_Area = var_ent_float_Radio*3.1416*(var_ent_float_Radio+var_ent_float_alturaInclinada)

# %%
# Salidas
print(var_proSal_float_Area)
# Out:
# 169.6464
