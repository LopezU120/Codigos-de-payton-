# %% [markdown]
# Elabore un algoritmo que lea los 3 lados de un triangulo cualquiera y calcule su área, considerar: si A, B y C son los lados, y S el semiperimetro.
#
# Autor: Juan Camilo Lopez
#
# Fecha: 06_09_2022
#
# version: 1.0

# %%
# Procesos de variables

# %%
# Captura de datos

# %%
# Procesos

# %%
# Salidas
