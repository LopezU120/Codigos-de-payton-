# %% [markdown]
# Camion que circula a 20m/s en 5s cambia su velocidad 25m/s es su velocidad final
#
# Autor: Grupo PP Noche
#
# Fecha: 04_09_2022
#
# Version: 1.0

# %%
# Declaracion de variables
var_ent_float_aceleracion = 00
var_ent_float_velocidadfinal = 25
var_ent_float_velocidadinicial = 20
var_ent_float_Posicion = 5
var_proSal_float_aceleracion = 00 # variable que almacena el resultado acerelacion

# %%
# Capturas de datos 
var_ent_float_velocidadfinal = float(input("velocidad final ; "))
var_ent_float_velocidadinicial = float(input("velocidad inicial ; "))
var_ent_float_Posicion = float(input("Posicion ; "))
# Out:
# velocidad final ; 25
# velocidad inicial ; 20
# Posicion ; 5

# %%
# Procesos
var_proSal_input_aceleracion = (var_ent_float_velocidadfinal-var_ent_float_velocidadinicial)/var_ent_float_Posicion

# %%
# Salidas
print(var_proSal_input_aceleracion)
# Out:
# 1.0
