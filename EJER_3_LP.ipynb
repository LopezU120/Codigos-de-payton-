# %% [markdown]
# Una locomotora  necesita 10s para alcanzar su velocidad normal
#
# velocidad normal 25m/s
#
# velocidad inicial 0
#
# autor: Juan Camilo Lopez
#
# Fecha: 06_09_2022
#
# version: 1.0

# %%
# Declaracion de viariables
var_ent_float_velocidadNormal = 0.0
var_ent_float_tiempo = 0.0
var_ent_float_velocidadIncial = 0.0
var_proSal_float_aceleracion = 0.0 # Variable que almacena 
var_proSal_float_espacio = 0.0 # Variable que almacena

# %%
# Captura de datos
var_ent_float_velocidadNormal = float(input("velocidad Normal ;"))
var_ent_float_tiempo = float(input("tiempo ;"))
var_ent_float_velocidadIncial = float(input("velocidad Inicial ;"))
# Out:
# velocidad Normal ;25
# tiempo ;10
# velocidad Inicial ;0

# %% [markdown]
# Velocidad Normal: 25
#
# tiempo: 10
#
# velocidad Inicial: 0

# %%
# Procesos
var_proSal_float_aceleracion = var_ent_float_velocidadNormal/var_ent_float_tiempo

# %%
# Procesos
var_proSal_float_espacio = (1/2)*var_proSal_float_aceleracion*(var_ent_float_tiempo**2)

# %%
# Salida 
print(var_proSal_float_aceleracion)
# Out:
# 2.5

# %%
# Salida
print(var_proSal_float_espacio)
# Out:
# 125.0
