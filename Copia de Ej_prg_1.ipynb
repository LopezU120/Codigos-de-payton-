# %% [markdown]
# Ejercicio 01
#
# Un camión circula por una carretea a 20m/s . En 5 s , su velocidad pasa a ser de 25 m/s.
#
# Autor: Grupo TP Noche
#
# Fecha: 03_09_2022
#
# Version: 1.0

# %%
# Declaracion de variables 
var_ent_float_velocidad_inicial = 00
var_ent_float_aceleracion = 0.0
var_ent_float_tiempo = 00
var_proSal_float_ResultadoAceleracion = 00 # variable que almacena el Resultado Aceleracion

# %%
# capturas de datos
var_ent_float_velocidad_inicial = float(input("velocidad inicial ; "))
var_ent_float_velocidad_final = float(input("velocidad final"))
var_ent_float_aceleracion = float(input("Aceleracion ; "))
var_ent_float_tiempo = float(input("tiempo ; "))

# %%
# Procesos
var_ent_cad_aceleracion = (var_ent_float_velocidad_inicial-var_ent_float_aceleracion)/var_ent_float_tiempo

# %%
# Salidas
print(var_ent_float_aceleracion)
# Out:
# 0.0
