# %%
class Coche():
# Atributos
    Ruedas=4
# Método 
    def desplazamiento(self):
        print("El Coche se esta desplazando sobre 4 ruedas")

# Programa principal

# Generar una instacia de la clase
# Instanciar un objeto 
# Declarar un objeto 
miVehiculo=Coche()
# Acceso al atributo
print("Mi coche tiene ", miVehiculo.Ruedas, "Ruedas")
# Forma que un objeto solicita que se ejecute un metodo
miVehiculo.desplazamiento()
# Out:
# Mi coche tiene  4 Ruedas
# El Coche se esta desplazando sobre 4 ruedas

# %%
class Coche():
# Atributos
    Ruedas=4
    Cilindraje=1000
    Combustible="Gasolina"
    Puertas=3
# Método 
    def desplazamiento(self):
        print("El Coche se esta desplazando sobre 4 ruedas")

# Programa principal

# Generar una instacia de la clase
# Instanciar un objeto 
# Declarar un objeto 
miVehiculo=Coche()
obj_miCarrito = Coche()
# Acceso al atributo
print("Mi coche tiene ", miVehiculo.Ruedas, "Ruedas")
print("Mi coche tiene ", miVehiculo.Cilindraje, "Ruedas")
print("Mi coche tiene ", miVehiculo.Combustible, "Ruedas")
print("Mi coche tiene ", miVehiculo.Puertas, "Ruedas")
# Forma que un objeto solicita que se ejecute un metodo
miVehiculo.desplazamiento()
obj_miCarrito.desplazamiento()
# Out:
# Mi coche tiene  4 Ruedas
# Mi coche tiene  1000 Ruedas
# Mi coche tiene  Gasolina Ruedas
# Mi coche tiene  3 Ruedas
# El Coche se esta desplazando sobre 4 ruedas
# El Coche se esta desplazando sobre 4 ruedas

# %%
class Coche():
# Atributos
    Ruedas=4
# Método 
    def desplazamiento(self):
        print("El Coche se esta desplazando sobre 4 ruedas")
class Moto():
    # Atributos
    Ruedas=2
# Método 
    def desplazamiento(self):
        print("El Moto se esta desplazando sobre 2 ruedas")
# Programa principal

# Generar una instacia de la clase
# Instanciar un objeto 
print("-----------------Primer Objeto Coche-----------------")
# Declarar un objeto 
miCoche=Coche()
# Acceso al atributo
print("Mi coche tiene ", miCoche.Ruedas, "Ruedas")
# Forma que un objeto solicita que se ejecute un metodo
miCoche.desplazamiento()
print("-----------------Segundo Objeto Moto----------------")
# Declarar un objeto 
miMoto=Moto()
# Acceso al atributo
print("Mi Moto tiene ", miMoto.Ruedas, "Ruedas")
# Forma que un objeto solicita que se ejecute un metodo
miMoto.desplazamiento()
# Out:
# -----------------Primer Objeto Coche-----------------
# Mi coche tiene  4 Ruedas
# El Coche se esta desplazando sobre 4 ruedas
# -----------------Segundo Objeto Moto----------------
# Mi Moto tiene  2 Ruedas
# El Moto se esta desplazando sobre 2 ruedas

# %%
# Constructor
class Cachorro():
    # Metodo Constructor
    def __init__(self, p_color,p_raza):
        self.color = p_color
        self.raza = p_raza

perrito = Cachorro("Marron claro", "Golden retriever")

print("Este es un Cachorro de la raza {} y de color {}".format(perrito.raza,perrito.color))
# Out:
# Este es un Cachorro de la raza Golden retriever y de color Marron claro

# %%
# Constructor
class Cachorro():
    # Metodo Constructor
    def __init__(self, p_color,p_raza):
        self.color = p_color
        self.raza = p_raza

perrito = Cachorro("Marron claro", "Golden retriever")
obj_perritodeVicky = Cachorro("Blanco", "Shitzu")
obj_perritoelbrayan = Cachorro("Negro", "Sin identificar")

print("Este es el perro sin dueño {} y de color {}".format(perrito.raza,perrito.color))
print("Este es el perro de vicky la raza es {} y de color {}".format(obj_perritodeVicky.raza,obj_perritodeVicky.color))
print("Este es el perro del BRAYAN la raza es {} y de color {}".format(obj_perritoelbrayan.raza,obj_perritoelbrayan.color))
# Out:
# Este es el perro sin dueño Golden retriever y de color Marron claro
# Este es el perro de vicky la raza es Shitzu y de color Blanco
# Este es el perro del BRAYAN la raza es Sin identificar y de color Negro

# %%
# Constructor
class Cachorro():
    # Metodo Constructor
    def __init__(self, p_color,p_raza,p_nombre):
        self.color = p_color
        self.raza = p_raza
        self.nombre = p_nombre
#Moduo Principal 
p_color = input("Color : ")
p_raza = input("Raza : ")
p_nombre = input("Nombre : ")

perrito = Cachorro(p_color,p_raza,p_nombre)
print("Este es un cachorro sin dueño y la es raza {} y el color es {} y se llama {} ".format(perrito.raza, perrito.color, perrito.nombre))
# Out:
# Color : Gris
# Raza : Lobo
# Nombre : Max
# Este es un cachorro sin dueño y la es raza Lobo y el color es Gris y se llama Max

# %%
class C_Rectangulo:
    def __init__(self,p_ancho,p_alto):
        self.at_ancho=p_ancho
        self.at_alto=p_alto

    def m_area(self):
        area=(self.at_alto*self.at_ancho)
        return area
    
    def m_perimetro(self):
        perimetro=(self.at_alto*2)+(self.at_ancho*2)
        return perimetro

r1=C_Rectangulo(4,2)
area=r1.m_area()
perimetro=r1.m_perimetro()
print("El area es : ", area)
print("El perimetro es : ", perimetro)

p_ancho = int(input("Ancho : "))
p_alto = int(input("Alto : "))

obj_rect2=C_Rectangulo(p_ancho,p_alto)

print("El area es : ", +obj_rect2.m_area())
print("El perimetro es : ", +obj_rect2.m_perimetro())
# Out:
# El area es :  8
# El perimetro es :  12
# Ancho : 7
# Alto : 6
# El area es :  42
# El perimetro es :  26

# %%
class C_Rectangulo:
    def __init__(self,p_ancho,p_alto,p_hipotenusa):
        self.at_ancho=p_ancho
        self.at_alto=p_alto

    def m_area(self):
        area=(self.at_alto*self.at_ancho)
        return area
    def m_hipotenusa(self):
        hipotenusa = sqrt self.at_)
    
    def m_perimetro(self):
        perimetro=(self.at_alto*2)+(self.at_ancho*2)
        return perimetro

r1=C_Rectangulo(4,2)
area=r1.m_area()
perimetro=r1.m_perimetro()
print("El area es : ", area)
print("El perimetro es : ", perimetro)

p_ancho = int(input("Ancho : "))
p_alto = int(input("Alto : "))

obj_rect2=C_Rectangulo(p_ancho,p_alto,p_hipotenusa)

print("El area es : ", +obj_rect2.m_area())
print("El perimetro es : ", +obj_rect2.m_perimetro())
